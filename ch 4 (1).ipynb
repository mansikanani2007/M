# %% [markdown]
# ## T-2 SYLLABUS
# - UNIT 4- REGRESSION MODELS ~ 10 MARKS
# - UNIT 5- CLASSIGICATION MODEL ~ 12 MARKS
# - UNIT 6- INTRO TO DEEP LEARNING ~ 3 MARKS

# %% [markdown]
# # UNIT- 4 REDRESSION MODELS

# %% [markdown]
# ## Three methods to analyse regression technique
# - Manual method
# - MS Excel based
# - python method

# %% [markdown]
# ## PYTHON BASED METHOD

# %%
import numpy as np
from sklearn.linear_model import LinearRegression

# %% [markdown]
# #### second Step
# - import dataset

# %%
x=np.array([60,62,67,70,71,72,75,78]).reshape(-1,1)

# %%
print(x)
# Out:
# [[60]
#  [62]
#  [67]
#  [70]
#  [71]
#  [72]
#  [75]
#  [78]]

# %%
y=np.array([140,155,159,179,192,200,212,214])
print(y)
# Out:
# [140 155 159 179 192 200 212 214]

# %% [markdown]
# ## third step
# - create model

# %%
model=LinearRegression()

# %% [markdown]
# ## fourth step

# %%
model.fit(x,y)
# Out:
# LinearRegression()

# %%
#fifth step 
# print the slope and intercept
# slope
print(model.coef_[0])
print(model.intercept_)
# Out:
# 4.372809095215539
# -121.98863098057802

# %%
slope=model.coef_[0]
intercept=model.intercept_
print(f"the linear regression equation is y={intercept:.2f}+{slope:.2f}*x")
# Out:
# the linear regression equation is y=-121.99+4.37*x

# %% [markdown]
# ## MODEL PREDICTION

# %% [markdown]
# ## using statsmodel libary

# %%
import statsmodels.api as sm
x=np.array([60,62,67,70,71,72,75,78]).reshape(-1,1)
y=np.array([140,155,159,179,192,200,212,214])
x_withconstant=sm.add_constant(x)
model=sm.OLS(y,x_withconstant).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.939
# Model:                            OLS   Adj. R-squared:                  0.928
# Method:                 Least Squares   F-statistic:                     91.68
# Date:                Fri, 30 Jan 2026   Prob (F-statistic):           7.41e-05
# Time:                        04:45:20   Log-Likelihood:                -26.233
# No. Observations:                   8   AIC:                             56.47
# Df Residuals:                       6   BIC:                             56.62
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       -121.9886     31.791     -3.837      0.009    -199.778     -44.200
# ...

# %%
import statsmodels.api as sm

# %% [markdown]
# # POLYNOMIAL REGRESSION

# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures

# %%
import seaborn as sns
iris=sns.load_dataset("iris")
iris.head(2)
# Out:
# ---------------------------------------------------------------------------
# SSLCertVerificationError                  Traceback (most recent call last)
# File C:\ProgramData\anaconda3\Lib\urllib\request.py:1319, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1318 try:
# -> 1319     h.request(req.get_method(), req.selector, req.data, headers,
#    1320               encode_chunked=req.has_header('Transfer-encoding'))
#    1321 except OSError as err: # timeout error
#
# File C:\ProgramData\anaconda3\Lib\http\client.py:1338, in HTTPConnection.request(self, method, url, body, headers, encode_chunked)
#    1337 """Send a complete request to the server."""
# -> 1338 self._send_request(method, url, body, headers, encode_chunked)
#
# File C:\ProgramData\anaconda3\Lib\http\client.py:1384, in HTTPConnection._send_request(self, method, url, body, headers, encode_chunked)
#    1383     body = _encode(body, 'body')
# ...

# %% [markdown]
# ### install ollama
# ### install claude
# ### ollama and claude extension vscode
# ### use ollama minimax 2.5 claude-
# ### install
